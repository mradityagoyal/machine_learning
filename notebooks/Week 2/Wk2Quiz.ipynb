# %%
import graphlab

# %%
# Limit number of worker processes. This preserves system memory, which prevents hosted notebooks from crashing.
graphlab.set_runtime_config('GRAPHLAB_DEFAULT_NUM_PYLAMBDA_WORKERS', 4)
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to mradityagoyal@gmail.com and will expire on December 17, 2017.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1487015534.log

# %% [markdown]
# Load some house sales data
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = graphlab.SFrame('home_data.gl/')
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
sales.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:60379/index.html
# Opening Canvas in default web browser.

# %%
train_data, test_data = sales.random_split(.8)

# %%
train_data.head()
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 10
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
import graphlab.aggregate as agg

# %%
neighborhood_data = sales.groupby(key_columns='zipcode', operations={'mean': agg.MEAN('price'), 'count':agg.COUNT()})
neighborhood_data
# Out:
# Columns:
# 	zipcode	str
# 	count	int
# 	mean	float
#
# Rows: 70
#
# Data:
# +---------+-------+---------------+
# | zipcode | count |      mean     |
# +---------+-------+---------------+
# |  98032  |  125  |   251296.24   |
# |  98115  |  583  |  619900.5506  |
# |  98075  |  359  | 790576.668524 |
# |  98034  |  545  | 521652.858716 |
# |  98106  |  335  |  319581.39403 |
# |  98024  |   81  | 580526.790123 |
# |  98122  |  290  | 634360.175862 |
# |  98010  |  100  |   423665.99   |
# |  98117  |  553  | 576795.007233 |
# |  98116  |  330  | 618634.178788 |
# +---------+-------+---------------+
# [70 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
neighborhood_data[neighborhood_data['mean']== neighborhood_data['mean'].max()]
# Out:
# Columns:
# 	zipcode	str
# 	count	int
# 	mean	float
#
# Rows: Unknown
#
# Data:
# +---------+-------+-----------+
# | zipcode | count |    mean   |
# +---------+-------+-----------+
# |  98039  |   50  | 2160606.6 |
# +---------+-------+-----------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
sales[0]
# Out:
# {'bathrooms': '1',
#  'bedrooms': '3',
#  'condition': 3,
#  'date': datetime.datetime(2014, 10, 13, 0, 0, tzinfo=GMT +0.0),
#  'floors': '1',
#  'grade': 7,
#  'id': '7129300520',
#  'lat': 47.51123398,
#  'long': -122.25677536,
#  'price': 221900,
#  'sqft_above': 1180,
#  'sqft_basement': 0,
#  'sqft_living': 1180,
#  'sqft_living15': 1340.0,
#  'sqft_lot': 5650,
#  'sqft_lot15': 5650.0,
#  'view': 0,
#  'waterfront': 0,
#  'yr_built': 1955,
#  'yr_renovated': 0,
#  'zipcode': '98178'}

# %%
def filter_by_sq_feet(sq_feet):
    if(sq_feet > 2000 and sq_feet < 4000):
        return True
    return False

# %%
len(sales[(sales['sqft_living'] > 2000) & (sales['sqft_living'] < 4000)]) / float(len(sales))
# Out:
# 0.4215518437977143
